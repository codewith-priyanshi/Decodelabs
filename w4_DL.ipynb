# %%
# !pip install pytesseract opencv-python pillow
# Out:
# Requirement already satisfied: pytesseract in c:\users\dell\anaconda3\lib\site-packages (0.3.13)
# Requirement already satisfied: opencv-python in c:\users\dell\anaconda3\lib\site-packages (4.13.0.92)
# Requirement already satisfied: pillow in c:\users\dell\anaconda3\lib\site-packages (11.1.0)
# Requirement already satisfied: packaging>=21.3 in c:\users\dell\anaconda3\lib\site-packages (from pytesseract) (24.2)
# Requirement already satisfied: numpy>=2 in c:\users\dell\anaconda3\lib\site-packages (from opencv-python) (2.1.3)

# %%
import cv2
import pytesseract
import matplotlib.pyplot as plt

# %%
pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"

# %%
image = cv2.imread(r"C:\Users\dell\Downloads\artical.jpg")

# %%
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
_, thresh = cv2.threshold(gray,150,255,cv2.THRESH_BINARY)

# %%
text = pytesseract.image_to_string(thresh)

# %%
print("Extracted Text:\n")
print(text)
# Out:
# Extracted Text:
#
# INDIAN LAKE’ —"A Si-year|
# old Cinéinnatian, vacationing with
# This wife, eight children and 18
# grandchildren. at the lake, suf
# fered a fatat heart atiack Tues-
# day as he rowed his boat after
# the motor had sheared a pin. Hel
# had been out on the lake only 2
# little: more than ten minutes.
# | Edmund F. Muenchen, a furni-|
# ture dealer in the Queen City, was|
# alone in the ‘boat.
#
# Dr. Frederick Kaylor, - Logan
# County coroner, ruled 1:07 as
# time of death, resulting from a
# heart attack.
#
# The victim was seen by Mrs.
# Paul Leary as he slumped. over|
# in the boat, drifting toward Para-
# ise Island. He was only a short]
# stance around a bend in the|
# lake. north of his rented cottage
# at White Cottage Park. An early!
# report, one of his grandchildren
# wag with him, was quickly dis-
# counted. Lakeview fire depart
# ment emergency squad, Lakel
# Shore Patrol, sherifi’s deputies!
# and Dr. Kaylor arrived shortly!
# after at the scene. Efforts to: res
# vive the. man were futile.
#
# In Boat On Lake
#
# taine priest, was’ called to -ad-
# minister . the jast rites’ after it
# was learned the Russells Point
# priest was away from his parish.
#
# There were no fishing poles in
# the boat and relatives theorized
# he was just going for a side.
#
# Dr. Kaylor said relatives told
# him he had recently visited |
# doctor, there he. complained of|
# shoulder. pains. He had been doc-
# toring fora fn attack.
#
# His body was returned’ to Cin-
# cinaati for final arrangements.
#
# 2 Rescue Crews
# Seek Lost Plane
#
# GUAYAQUIL, Ecuador. (AP}—]
# ‘Two rescue parties struggled up|
# 15.42%-foothigh Mt. Pichincha .to4
# day. trying to reach the wreckage
# lof a U.S, military transport in}
# which it was feared 18 persons}
# died.
#
# Air searchers spotted the wreck-|
# lage 14,000 feat up the mountain;
# Tuesday and reported they’ saw no|
#
# ' Rev. Charles Conrad, Bellefon-]
#
# isten of life.

# %%
with open("output.txt","w") as file:
    file.write(text)

print("Text Saved Successfully")
